# %%
import pandas as pd
housing = pd.read_csv('./Assignment-2/AmesHousingSetA.csv')
housing
# Out:
#             PID  MS.SubClass MS.Zoning  Lot.Frontage  Lot.Area Street Alley  \
# 0     526350040           20        RH          80.0     11622   Pave   NaN
# 1     526351010           20        RL          81.0     14267   Pave   NaN
# 2     526353030           20        RL          93.0     11160   Pave   NaN
# 3     527105010           60        RL          74.0     13830   Pave   NaN
# 4     527105030           60        RL          78.0      9978   Pave   NaN
# 5     527146030          120        RL          39.0      5389   Pave   NaN
# 6     527163010           60        RL          75.0     10000   Pave   NaN
# 7     527165230           20        RL           NaN      7980   Pave   NaN
# 8     527180040           20        RL          85.0     10176   Pave   NaN
# 9     527216070           60        RL          47.0     53504   Pave   NaN
# 10    527225035           50        RL         152.0     12134   Pave   NaN
# ...
